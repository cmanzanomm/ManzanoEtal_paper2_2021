# %%
#importamos libreríasf
import pandas as pd
import numpy as np
#import matplotlib.pyplot as plt

#plt.rcParams['figure.figsize'] = (16, 9)
#plt.style.use('ggplot')

# Gráficos
# ==============================================================================
import matplotlib.pyplot as plt
import matplotlib.font_manager
from matplotlib import style
style.use('ggplot') or plt.style.use('ggplot')

# Preprocesado y modelado
# ==============================================================================
from sklearn.decomposition import PCA
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import scale

# Configuración warnings
# ==============================================================================
import warnings


import os
import glob

"""crea entorno grÃ¡fico"""
plt.rcParams['figure.figsize'] = (40, 50)
plt.style.use('ggplot')

# Primero especificamos un patrón del archivo y lo pasamos como parámetro en la función glob
os.chdir("..\\Datasets")
os.getcwd()
csv_files = glob.glob('*.csv')
# Mostrar el archivo csv_files, el cual es una lista de nombres
print(csv_files)

list_data = []
  
# Escribimos un loop que irá a través de cada uno de los nombres de archivo a través de globbing y el resultado final será la lista dataframes

for filename in csv_files:
    data = pd.read_csv(filename)
    list_data.append(data)

#Para chequear que todo está bien, mostramos la list_data por consola
#list_data
 
df = pd.concat(list_data,ignore_index=True)

#tipos=df.dtypes  #tipos de datos de campos

"""información datos"""
print(df.head(5))
print('Cantidad de Filas y columnas:',df.shape)
print('Nombre columnas:',df.columns)

"""Columnas, nulos y tipo de datos"""
print(df.info())

"""descripción estadística de los datos numéricos"""
print(df.describe())

#cargamos los datos de entrada

print(df.tail(10))

"""correlación entre los datos"""
#corr = df.set_index('Label').corr()
#sm.graphics.plot_corr(corr, xnames=list(corr.columns))
#plt.show()

df2=df[['Flow_Duration', 'Tot_Fwd_Pkts', 'Tot_Bwd_Pkts','TotLen_Fwd_Pkts',
       'TotLen_Bwd_Pkts', 'Fwd_Pkt_Len_Min', 'Bwd_Pkt_Len_Min',
       'Fwd_Pkt_Len_Max', 'Bwd_Pkt_Len_Max', 'Fwd_Pkt_Len_Mean',
       'Bwd_Pkt_Len_Mean', 'Fwd_Pkt_Len_Std', 'Bwd_Pkt_Len_Std', 'Flow_Pkts/s',
       'Flow_Byts/s']]

df2_PCA=df[['Flow_Duration', 'Tot_Fwd_Pkts', 'Tot_Bwd_Pkts','TotLen_Fwd_Pkts',
       'TotLen_Bwd_Pkts', 'Fwd_Pkt_Len_Min', 'Bwd_Pkt_Len_Min',
       'Fwd_Pkt_Len_Max', 'Bwd_Pkt_Len_Max', 'Fwd_Pkt_Len_Mean',
       'Bwd_Pkt_Len_Mean', 'Fwd_Pkt_Len_Std', 'Bwd_Pkt_Len_Std', 'Flow_Pkts/s',
       'Flow_Byts/s']]

df3=df[['Label']]

"""convertir columna tipo dato str a int"""
df2['Label']=df3[['Label']]

"""desordena el dataset"""

df2=df2.sort_values('Fwd_Pkt_Len_Min')
df2 = df2[df2['Label'].isin([1,2,3,4])]

""" convertir valores número la clase"""
df2['Label'] = df2['Label'].replace(1,"Benigno")
df2['Label'] = df2['Label'].replace(2,"Malware")
df2['Label'] = df2['Label'].replace(3,"Malware")
df2['Label'] = df2['Label'].replace(4,"Malware")
#print(df2.head(10))
#print(df2.groupby('Label').size())


dff=df2[:]
dff1 = dff[dff.Label == 'Malware']
dff = dff.drop(dff[dff['Label'] == 'Malware'].index)
a = dff1.iloc[0:134800,]
df2 = pd.concat([dff,a])


print(df2.groupby('Label').size())



df2_PCA_Standar = StandardScaler().fit_transform(df2_PCA)

print(df2_PCA_Standar)


print('----------------------')
print('Media de cada variable')
print('----------------------')
#print(df2_PCA.mean(axis=0))

print('-------------------------')
print('Varianza de cada variable')
print('-------------------------')
#print(df2_PCA.var(axis=0))

# Entrenamiento modelo PCA con escalado de los datos
# ==============================================================================
pca_pipe = make_pipeline(StandardScaler(), PCA())
pca_pipe.fit(df2_PCA)

# Se extrae el modelo entrenado del pipeline
modelo_pca = pca_pipe.named_steps['pca']

#print(modelo_pca)

# Se combierte el array a dataframe para añadir nombres a los ejes.
datos2=pd.DataFrame(
    data    = modelo_pca.components_,
    columns = df2_PCA.columns,
   # index   = ['PC1', 'PC2', 'PC3', 'PC4','PC5'
	#		   ,'PC6','PC7']


index   = ['PC1', 'PC2', 'PC3', 'PC4','PC5'
			   ,'PC6','PC7','PC8','PC9','PC10'
			   ,'PC11','PC12','PC13','PC14','PC15']
)



print(datos2)
# Heatmap componentes
# ==============================================================================
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(16, 8))
componentes = modelo_pca.components_
plt.imshow(componentes.T, cmap='viridis', aspect='auto')
plt.yticks(range(len(datos2.columns)), datos2.columns)
plt.xticks(range(len(datos2.columns)), np.arange(modelo_pca.n_components_) + 1)
plt.grid(False)
plt.colorbar();

# ==============================================================================
print('----------------------------------------------------')
print('Porcentaje de varianza explicada por cada componente')
print('----------------------------------------------------')
print(modelo_pca.explained_variance_ratio_)

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(6, 4))
ax.bar(
    x      = np.arange(modelo_pca.n_components_) + 1,
    height = modelo_pca.explained_variance_ratio_
)

for x, y in zip(np.arange(len(datos2.columns)) + 1, modelo_pca.explained_variance_ratio_):
    label = round(y, 2)
    ax.annotate(
        label,
        (x,y),
        textcoords="offset points",
        xytext=(0,10),
        ha='center'
    )

ax.set_xticks(np.arange(modelo_pca.n_components_) + 1)
ax.set_ylim(0, 1.1)
ax.set_title('Porcentaje de varianza explicada por cada componente')
ax.set_xlabel('Componente principal')
ax.set_ylabel('Por. varianza explicada');



# Porcentaje de varianza explicada acumulada
# ==============================================================================
prop_varianza_acum = modelo_pca.explained_variance_ratio_.cumsum()
print('------------------------------------------')
print('Porcentaje de varianza explicada acumulada')
print('------------------------------------------')
print(prop_varianza_acum)

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(6, 4))
ax.plot(
    np.arange(len(datos2.columns)) + 1,
    prop_varianza_acum,
    marker = 'o'
)

for x, y in zip(np.arange(len(datos2.columns)) + 1, prop_varianza_acum):
    label = round(y, 2)
    ax.annotate(
        label,
        (x,y),
        textcoords="offset points",
        xytext=(0,10),
        ha='center'
    )
    
ax.set_ylim(0, 1.1)
ax.set_xticks(np.arange(modelo_pca.n_components_) + 1)
ax.set_title('Porcentaje de varianza explicada acumulada')
ax.set_xlabel('Componente principal')
ax.set_ylabel('Por. varianza acumulada');

# Porcentaje de varianza explicada acumulada
# ==============================================================================
prop_varianza_acum = modelo_pca.explained_variance_ratio_.cumsum()
print('------------------------------------------')
print('Porcentaje de varianza explicada acumulada')
print('------------------------------------------')
print(prop_varianza_acum)

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(6, 4))
ax.plot(
    np.arange(len(datos2.columns)) + 1,
    prop_varianza_acum,
    marker = 'o'
)

for x, y in zip(np.arange(len(datos2.columns)) + 1, prop_varianza_acum):
    label = round(y, 2)
    ax.annotate(
        label,
        (x,y),
        textcoords="offset points",
        xytext=(0,10),
        ha='center'
    )
    
ax.set_ylim(0, 1.1)
ax.set_xticks(np.arange(modelo_pca.n_components_) + 1)
ax.set_title('Porcentaje de varianza explicada acumulada')
ax.set_xlabel('Componente principal')
ax.set_ylabel('Por. varianza acumulada');
# Out:
# ['benign-2c .csv', 'malware.csv']
#    Flow_Duration  Tot_Fwd_Pkts  Tot_Bwd_Pkts  TotLen_Fwd_Pkts  \
# 0           5870             2             0              813
# 1           1499             2             0              128
# 2             16             0             2                0
# 3          46435             1             1               79
# 4              0             1             0              356
#
#    TotLen_Bwd_Pkts  Fwd_Pkt_Len_Min  Bwd_Pkt_Len_Min  Fwd_Pkt_Len_Max  \
# 0                0               83             -1.0              730
# 1                0               64             -1.0               64
# 2              159               -1             52.0               -1
# 3               95               79             95.0               79
# 4                0              356             -1.0              356
#
#    Bwd_Pkt_Len_Max  Fwd_Pkt_Len_Mean  Bwd_Pkt_Len_Mean  Fwd_Pkt_Len_Std  \
# 0               -1             406.5               0.0       457.496995
# 1               -1              64.0               0.0         1.000000
# 2              107               0.0              79.5         0.000000
# 3               95              79.0              95.0         0.000000
# 4               -1             356.0               0.0         0.000000
#
#    Bwd_Pkt_Len_Std    Flow_Pkts/s   Flow_Byts/s  Label
# 0         0.000000     340.715503  1.385009e+05      1
# 1         0.000000    1334.222815  8.539026e+04      1
# 2        38.878014  125000.000000  9.937500e+06      1
# 3         0.000000      43.070959  3.747173e+03      1
# 4         0.000000       0.000000  0.000000e+00      1
# Cantidad de Filas y columnas: (293333, 16)
# Nombre columnas: Index(['Flow_Duration', 'Tot_Fwd_Pkts', 'Tot_Bwd_Pkts', 'TotLen_Fwd_Pkts',
#        'TotLen_Bwd_Pkts', 'Fwd_Pkt_Len_Min', 'Bwd_Pkt_Len_Min',
#        'Fwd_Pkt_Len_Max', 'Bwd_Pkt_Len_Max', 'Fwd_Pkt_Len_Mean',
#        'Bwd_Pkt_Len_Mean', 'Fwd_Pkt_Len_Std', 'Bwd_Pkt_Len_Std', 'Flow_Pkts/s',
#        'Flow_Byts/s', 'Label'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 293333 entries, 0 to 293332
# Data columns (total 16 columns):
# Flow_Duration       293333 non-null int64
# Tot_Fwd_Pkts        293333 non-null int64
# Tot_Bwd_Pkts        293333 non-null int64
# TotLen_Fwd_Pkts     293333 non-null int64
# TotLen_Bwd_Pkts     293333 non-null int64
# Fwd_Pkt_Len_Min     293333 non-null int64
# Bwd_Pkt_Len_Min     293333 non-null float64
# Fwd_Pkt_Len_Max     293333 non-null int64
# Bwd_Pkt_Len_Max     293333 non-null int64
# Fwd_Pkt_Len_Mean    293333 non-null float64
# Bwd_Pkt_Len_Mean    293333 non-null float64
# Fwd_Pkt_Len_Std     293333 non-null float64
# Bwd_Pkt_Len_Std     293333 non-null float64
# Flow_Pkts/s         293333 non-null float64
# Flow_Byts/s         293333 non-null float64
# Label               293333 non-null int64
# dtypes: float64(7), int64(9)
# memory usage: 35.8 MB
# None
#        Flow_Duration  Tot_Fwd_Pkts   Tot_Bwd_Pkts  TotLen_Fwd_Pkts  \
# count   2.933330e+05  2.933330e+05  293333.000000     2.933330e+05
# mean    2.828950e+07  3.864145e+04       6.313695     1.112911e+03
# std     1.999058e+08  6.429386e+06     157.698740     2.336930e+04
# min    -1.800000e+01  0.000000e+00       0.000000     0.000000e+00
# 25%     0.000000e+00  1.000000e+00       0.000000     1.560000e+02
# 50%     5.129100e+04  4.000000e+00       2.000000     4.360000e+02
# 75%     5.481253e+06  1.400000e+01       6.000000     1.499000e+03
# max     1.154108e+10  3.318803e+09   53758.000000     1.220839e+07
#
#        TotLen_Bwd_Pkts  Fwd_Pkt_Len_Min  Bwd_Pkt_Len_Min  Fwd_Pkt_Len_Max  \
# count     2.933330e+05    293333.000000    293333.000000    293333.000000
# mean      1.010601e+04       244.073674        47.039805       255.224335
# std       2.284979e+05       330.940856        92.317203       313.704548
# min       0.000000e+00        -1.000000        -1.000000        -1.000000
# 25%       0.000000e+00        52.000000        -1.000000        52.000000
# 50%       1.306000e+03       182.000000        -1.000000        67.000000
# 75%       1.356200e+04       420.000000        52.000000       420.000000
# max       7.463559e+07    126552.000000      1390.000000      1500.000000
#
#        Bwd_Pkt_Len_Max  Fwd_Pkt_Len_Mean  Bwd_Pkt_Len_Mean  Fwd_Pkt_Len_Std  \
# count    293333.000000     293333.000000     293333.000000    293333.000000
# mean        202.769259        150.490722        115.501735        64.051232
# std         387.007184        153.853141        218.544111       137.841367
# min          -1.000000          0.000000          0.000000         0.000000
# 25%          -1.000000         52.000000          0.000000         0.000000
# 50%          -1.000000         65.000000          0.000000         1.000000
# 75%         217.000000        218.666667        113.000000        21.897488
# max        1390.000000       1390.000000       1390.000000       954.593631
#
#        Bwd_Pkt_Len_Std   Flow_Pkts/s   Flow_Byts/s          Label
# count    293333.000000  2.933330e+05  2.933330e+05  293333.000000
# mean         69.603111  3.504063e+04  1.825474e+06       2.175708
# std         164.955297  1.761520e+05  9.649653e+06       1.263217
# min           0.000000  0.000000e+00  0.000000e+00       1.000000
# 25%           0.000000  0.000000e+00  0.000000e+00       1.000000
# 50%           0.000000  6.960604e-01  8.643605e+01       2.000000
# 75%           4.564355  5.964630e+01  6.409914e+03       4.000000
# max         946.108345  2.000000e+06  7.440000e+08       4.000000
#         Flow_Duration  Tot_Fwd_Pkts  Tot_Bwd_Pkts  TotLen_Fwd_Pkts  \
# 293323         407759            20             9              507
# 293324         260035             4             2             2635
# 293325         549153             2             8              981
# 293326           1621             2             8              645
# 293327          49378             6            15              225
# 293328          80153             9            16              157
# 293329       53145261           119             3             1231
# 293330              0             7            10              431
# 293331          52616            20             8             1333
# 293332       19687378            10             1             2614
#
#         TotLen_Bwd_Pkts  Fwd_Pkt_Len_Min  Bwd_Pkt_Len_Min  Fwd_Pkt_Len_Max  \
# 293323            25666              277            220.0               62
# 293324              823              614             40.0               40
# 293325            25961               11             40.0              962
# 293326             6218               61            189.0               61
# 293327            27183              636             -1.0              784
# 293328            15235              442             52.0               52
# 293329             9997              412            758.0              853
# 293330             6500              179             -1.0               52
# 293331             6537              269            298.0               65
# 293332            14738              750             52.0              249
#
#         Bwd_Pkt_Len_Max  Fwd_Pkt_Len_Mean  Bwd_Pkt_Len_Mean  Fwd_Pkt_Len_Std  \
# 293323              220              62.0        220.000000         0.000000
# 293324               40              40.0         40.000000         0.000000
# 293325              267             354.0        119.666667       526.637921
# 293326              189              61.0        189.000000         0.000000
# 293327               -1             296.0          0.000000       422.619805
# 293328               52              52.0         52.000000         0.000000
# 293329             1390             319.0       1179.666667       413.634380
# 293330               -1              52.0          0.000000         0.000000
# 293331              298              65.0        298.000000         0.000000
# 293332             1390              85.5        466.636364        68.082874
#
#         Bwd_Pkt_Len_Std    Flow_Pkts/s   Flow_Byts/s  Label
# 293323         0.000000       2.040552  1.061087e+02      4
# 293324         0.000000      44.251704  4.734932e+03      4
# 293325       127.733446       4.347836  1.382612e+03      3
# 293326         0.000000    1174.398121  6.106870e+04      4
# 293327         0.000000       0.364855  1.459419e+01      3
# 293328         0.000000  142857.142900  9.642857e+06      3
# 293329       325.847306      54.234347  3.742170e+03      2
# 293330         0.000000      18.411968  9.574223e+02      3
# 293331         0.000000      65.864805  1.998237e+04      2
# 293332       596.436212     257.499678  1.338998e+04      4
# Label
# Benigno    137907
# Malware    134800
# dtype: int64
# [[-0.141485   -0.00600983 -0.0400365  ... -0.42195208 -0.19698878
#   -0.17482249]
#  [-0.14150687 -0.00600983 -0.0400365  ... -0.42195208 -0.19134871
#   -0.18032639]
#  [-0.14151429 -0.00601014 -0.02735407 ... -0.18626349  0.51069245
#    0.84065609]
#  ...
#  [-0.14151437 -0.00600905  0.02337566 ... -0.42195208 -0.19881847
#   -0.18907623]
#  [-0.14125116 -0.00600703  0.01069323 ... -0.42195208 -0.19854908
#   -0.18710466]
#  [-0.04303095 -0.00600859 -0.03369528 ...  3.19379862 -0.19746119
#   -0.18778784]]
# ----------------------
# Media de cada variable
# ----------------------
# -------------------------
# Varianza de cada variable
# -------------------------
#       Flow_Duration  Tot_Fwd_Pkts  Tot_Bwd_Pkts  TotLen_Fwd_Pkts  \
# PC1        0.001494      0.000943      0.039245         0.020077
# PC2        0.011598     -0.001681      0.662433         0.209521
# PC3       -0.004956      0.003131      0.134771         0.050707
# PC4       -0.011995      0.006384      0.138654         0.071207
# PC5       -0.834545      0.278154      0.006944        -0.015059
# PC6        0.388772      0.771697     -0.007386        -0.004032
# PC7       -0.145131      0.569230      0.013945        -0.045828
# PC8        0.007678      0.037186     -0.129488         0.968875
# PC9       -0.358240     -0.038971     -0.018056         0.072442
# PC10      -0.051210     -0.011612      0.004835         0.009635
# PC11       0.001658      0.000250      0.013533        -0.001043
# PC12      -0.000073     -0.000049     -0.000113         0.000087
# PC13       0.000006      0.000326     -0.709795         0.040593
# PC14      -0.000873      0.000149     -0.028393         0.001429
# PC15       0.001615     -0.000145      0.006427         0.001814
#
#       TotLen_Bwd_Pkts  Fwd_Pkt_Len_Min  Bwd_Pkt_Len_Min  Fwd_Pkt_Len_Max  \
# PC1          0.034862        -0.005000         0.100093         0.424643
# PC2          0.656839        -0.051648         0.081405        -0.118247
# PC3          0.133034         0.085979        -0.082912         0.081523
# PC4          0.138503         0.199857        -0.426576         0.360489
# PC5          0.009079         0.261630         0.339049         0.021091
# PC6         -0.005235         0.481802        -0.018965        -0.059740
# PC7          0.012759        -0.764103        -0.186989         0.055659
# PC8         -0.187020        -0.053540         0.066112        -0.000338
# PC9         -0.022902         0.188726        -0.725594        -0.167688
# PC10         0.013451         0.164372         0.087499         0.099723
# PC11         0.031969         0.002901         0.312194        -0.166407
# PC12        -0.000138         0.000976        -0.000702        -0.005508
# PC13         0.702037        -0.004378        -0.005981        -0.025130
# PC14         0.025159        -0.001804         0.047552         0.744014
# PC15        -0.000610        -0.001404         0.077192         0.204968
#
#       Bwd_Pkt_Len_Max  Fwd_Pkt_Len_Mean  Bwd_Pkt_Len_Mean  Fwd_Pkt_Len_Std  \
# PC1          0.467973          0.206422          0.405782         0.412509
# PC2          0.050632         -0.159698          0.100879        -0.089053
# PC3         -0.104340          0.181632         -0.113502         0.012256
# PC4         -0.238534          0.511543         -0.344639         0.235075
# PC5         -0.037293          0.133538          0.062789        -0.042170
# PC6          0.053156         -0.055539          0.058212        -0.072939
# PC7         -0.040612         -0.030988         -0.109167         0.120518
# PC8         -0.011032          0.011813         -0.003206         0.001163
# PC9          0.190653         -0.292727          0.014747        -0.136770
# PC10        -0.140441         -0.621117         -0.260736         0.686235
# PC11         0.149550          0.123229         -0.707445        -0.076055
# PC12        -0.002852         -0.003051         -0.002429         0.005851
# PC13        -0.010238          0.014434          0.021218         0.015293
# PC14         0.183255         -0.345492         -0.211934        -0.482529
# PC15        -0.769761         -0.094658          0.245347        -0.127903
#
#       Bwd_Pkt_Len_Std  Flow_Pkts/s  Flow_Byts/s
# PC1          0.454600    -0.041945    -0.040256
# PC2          0.002572     0.090094     0.090187
# PC3         -0.085586    -0.662115    -0.661808
# PC4         -0.118755     0.220552     0.221627
# PC5         -0.125363     0.024588     0.026355
# PC6          0.049618     0.007325     0.006783
# PC7          0.019628    -0.023265    -0.023722
# PC8         -0.024061     0.001846     0.001927
# PC9          0.361341    -0.032000    -0.035639
# PC10        -0.080427    -0.022141    -0.030913
# PC11         0.574269     0.005255     0.000498
# PC12         0.003831    -0.707339     0.706801
# PC13         0.001448    -0.000487    -0.000706
# PC14        -0.109525    -0.003119     0.005834
# PC15         0.523383     0.001364    -0.001407
# ----------------------------------------------------
# Porcentaje de varianza explicada por cada componente
# ----------------------------------------------------
# [0.24784486 0.13376622 0.12650063 0.11608997 0.0685171  0.06799325
#  0.06385726 0.06319906 0.05614958 0.02937059 0.01121595 0.0077717
#  0.00387868 0.00266012 0.00118503]
# ------------------------------------------
# Porcentaje de varianza explicada acumulada
# ------------------------------------------
# [0.24784486 0.38161108 0.50811171 0.62420168 0.69271878 0.76071203
#  0.8245693  0.88776836 0.94391794 0.97328853 0.98450447 0.99227617
#  0.99615485 0.99881497 1.        ]
# ------------------------------------------
# Porcentaje de varianza explicada acumulada
# ------------------------------------------
# [0.24784486 0.38161108 0.50811171 0.62420168 0.69271878 0.76071203
#  0.8245693  0.88776836 0.94391794 0.97328853 0.98450447 0.99227617
#  0.99615485 0.99881497 1.        ]
